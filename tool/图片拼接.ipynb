# %%
import matplotlib.image as mpimg
import os

dir_path1 = 'pic\\'
L0,L2,L4,L6,L8,L10=[],[],[],[],[],[]
L = os.listdir( dir_path1 )
for i in L:
    if 'n=20' in i:
        L10.append(i)
    if 'n=18' in i:
        L8.append(i)    
    if 'n=16' in i:
        L6.append(i)
    if 'n=14' in i:
        L4.append(i)
    if 'n=12' in i:
        L2.append(i)
    if 'n=10' in i:
        L0.append(i)

L=[L0,L2,L4,L6,L8,L10]
for i in L:
    axes_num=0
    fig,axes=plt.subplots(8,1,figsize=(4,16),dpi=200)
    for j in i:
        # print(j)
        img_path = 'pic\\' + j
        img = mpimg.imread(img_path)[100:600,40:540]
        axes[axes_num].imshow(img)
        axes[axes_num].set_xticks([])
        axes[axes_num].set_yticks([])
        axes[axes_num].spines['right'].set_visible(False)
        axes[axes_num].spines['top'].set_visible(False)
        axes[axes_num].spines['bottom'].set_visible(False)
        axes[axes_num].spines['left'].set_visible(False)
        axes_num+=1
        # break
    fig.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9, wspace=0.01, hspace=0.01)
    # break
